# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import pingouin as pg
from lets_plot import *

LetsPlot.setup_html(no_js=True)

# %%
read_file = pd.read_excel ("/Users/apple/Documents/GitHub/YunlongWei_Homework/Lab2_dataset/Public-goods-experimental-data.xlsx") 

read_file.to_csv ("Public-goods-experimental-data.csv", 
				index = None, 
				header=True) 
	

df = pd.DataFrame(pd.read_csv("Public-goods-experimental-data.csv"))
# Out:
# /Users/apple/Documents/GitHub/YunlongWei_Homework/.venv/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df.head()
# Out:
#   Contributions without punishment (Figure 3 in Herrmann, Thoni, and Gachter (2008))  \
# 0                                             Period
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#            Unnamed: 1          Unnamed: 2 Unnamed: 3          Unnamed: 4  \
# 0          Copenhagen     Dnipropetrovs’k      Minsk          St. Gallen
# 1  14.102941176470589  10.954545272727273    12.7941             13.6875
# 2  14.132352941176471  12.636363454545455    12.3382         12.80206675
# 3  13.720588235294118  12.068181636363636    12.5882  12.354183500000001
# 4  12.897058823529411           11.181818    12.2647         10.60418325
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8          Unnamed: 9 Unnamed: 10  \
# 0     Muscat     Samara     Zurich     Boston                Bonn     Chengdu
# ...
